# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray
# Out:
# array([[85, 87, 88, ..., 26, 26, 26],
#        [85, 86, 86, ..., 26, 26, 26],
#        [85, 84, 84, ..., 26, 26, 26],
#        ...,
#        [25, 26, 26, ..., 27, 28, 28],
#        [26, 26, 25, ..., 27, 28, 28],
#        [26, 25, 25, ..., 27, 28, 28]], dtype=uint8)

# %%
img_gray.max()
# Out:
# 209

# %%
plt.imshow(img_gray,cmap="gray")

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img,(1000,650))

# %%
plt.imshow(new_img
          )

# %%
flip = cv2.flip(new_img,1)

# %%
cv2.imwrite("Flipped.jpg",flip)
# Out:
# True

# %%
plt.imshow(flip)

# %%
flip_color = cv2.cvtColor(flip,cv2.COLOR_BGR2RGB)

# %%
cv2.imwrite('Colored_flip.jpg',flip_color)
# Out:
# True
